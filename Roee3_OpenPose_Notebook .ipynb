# %%
import cv2
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
protoFile = "pose/mpi/pose_deploy_linevec_faster_4_stages.prototxt"
weightsFile = "pose/mpi/pose_iter_160000.caffemodel"
nPoints = 15
POSE_PAIRS = [[0,1], [1,2], [2,3], [3,4], [1,5], [5,6], [6,7], [1,14], [14,8], [8,9], [9,10], [14,11], [11,12], [12,13] ]

# %% [markdown]
# ## Load trained VGG network

# %%
net = cv2.dnn.readNetFromCaffe(protoFile, weightsFile)

inWidth = 368
inHeight = 368

# %% [markdown]
# ## Pass all images through the network to extract joint positions.
# ## Load into dataframe

# %%
counter = 0
for filename in os.listdir('.'):
    try:
    
        if filename.endswith(".jpg") : 
            print(counter)
            frame = cv2.imread(filename)
            frameCopy = np.copy(frame)
            frameWidth = frame.shape[1]
            frameHeight = frame.shape[0]
            threshold = 0.1

            inpBlob = cv2.dnn.blobFromImage(frame, 1.0 / 255, (inWidth, inHeight),
                                      (0, 0, 0), swapRB=False, crop=False)

            net.setInput(inpBlob)

            output = net.forward()
            H = output.shape[2]
            W = output.shape[3]

            points = []

            for i in range(nPoints):
                # confidence map of corresponding body's part.
                probMap = output[0, i, :, :]

                # Find global maxima of the probMap.
                minVal, prob, minLoc, point = cv2.minMaxLoc(probMap)

                # Scale the point to fit on the original image
                x = (frameWidth * point[0]) / W
                y = (frameHeight * point[1]) / H

                if prob > threshold : 
                    cv2.circle(frameCopy, (int(x), int(y)), 8, (0, 255, 255), thickness=-1, lineType=cv2.FILLED)
                    cv2.putText(frameCopy, "{}".format(i), (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, lineType=cv2.LINE_AA)
                    cv2.circle(frame, (int(x), int(y)), 8, (0, 0, 255), thickness=-1, lineType=cv2.FILLED)

                    # Add the point to the list if the probability is greater than the threshold
                    points.append((int(x), int(y)))
                else :
                    points.append(None)
    #         print(points)
            flat_point = [e for l in points for e in l]
            flat_array = np.array(flat_point)
            flat_array = flat_array / flat_array.max()

            point_dict = {i:flat_array[i] for i in np.arange(len(flat_array))}
            
            if filename.find('right') >= 0:
                point_dict['label'] = 1
            else:
                point_dict['label'] = 0
                
            if counter == 0:

                point_df = pd.DataFrame(point_dict, index=[0])
            else:
                point_df.loc[counter] = pd.Series(point_dict)
    
            counter += 1


    except:
        counter += 1
        print(filename)
        continue
# Out:
# 0
# 1
# wrong_resized_image_475.jpg
# 2
# wrong_resized_image_229.jpg
# 3
# 4
# right_resized_image891.jpg
# 5
# right_resized_image_9_965.jpg
# 6
# 7
# right_resized_image933.jpg
# 8
# 9
# 10
# 11
# 12
# wrong_resized_image_2246.jpg
# 13
# wrong_resized_image_6_530.jpg
# 14
# 15
# wrong_resized_20181231_163249.jpg
# 16
# 17
# 18
# 19
# 20
# right_resized_image_234.jpg
# 21
# wrong_resized_image_7_550.jpg
# 22
# wrong_resized_image_7_60.jpg
# 23
# 24
# 25
# 26
# 27
# 28
# wrong_resized_image_2426.jpg
# 29
# right_resized_image_2313.jpg
# 30
# right_resized_20190103_144739(0).jpg
# 31
# wrong_resized_image_7_965.jpg
# 32
# right_resized_20190103_144849.jpg
# 33
# wrong_resized_20190103_145302.jpg
# 34
# wrong_resized_image_7_1095.jpg
# 35
# 36
# 37
# wrong_resized_image_2523.jpg
# 38
# right_resized_image_2276.jpg
# 39
# wrong_resized_image_8_290.jpg
# 40
# wrong_resized_image_6_370.jpg
# 41
# wrong_resized_image_5_65.jpg
# 42
# wrong_resized_image_345.jpg
# 43
# 44
# right_resized_20190103_155320.jpg
# 45
# right_resized_20190103_145007.jpg
# 46
# wrong_resized_20190103_145306.jpg
# 47
# wrong_resized_image_40.jpg
# 48
# right_resized_20190103_145305.jpg
# 49
# 50
# 51
# 52
# right_resized_image_9_610.jpg
# 53
# right_resized_image_2638 - Copy.jpg
# 54
# right_resized_image_5_40.jpg
# 55
# 56
# 57
# 58
# wrong_resized_image_2377.jpg
# 59
# wrong_resized_image_9_630.jpg
# 60
# 61
# 62
# 63
# right_resized_20190103_155322.jpg
# 64
# 65
# 66
# 67
# 68
# wrong_resized_20190103_145435.jpg
# 69
# wrong_resized_image_7_1180.jpg
# 70
# 71
# 72
# 73
# 74
# wrong_resized_20190103_155419.jpg
# 75
# right_resized_20190103_145247.jpg
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# wrong_resized_20190103_144423.jpg
# 87
# wrong_resized_image_2524.jpg
# 88
# 89
# right_resized_image_2235.jpg
# 90
# wrong_resized_20190103_155403.jpg
# 91
# 92
# 93
# right_resized_image_8_355.jpg
# 94
# wrong_resized_20190103_145403.jpg
# 95
# wrong_resized_20190103_145423.jpg
# 96
# 97
# 98
# 99
# wrong_resized_20190103_155817.jpg
# 100
# right_resized_image_5_185.jpg
# 101
# right_resized_image_7_675.jpg
# 102
# wrong_resized_image863.jpg
# 103
# wrong_resized_image_2147.jpg
# 104
# 105
# right_resized_image812.jpg
# 106
# 107
# 108
# wrong_resized_image_7_1035.jpg
# 109
# wrong_resized_20190103_155630.jpg
# 110
# right_resized_20190102_181700.jpg
# 111
# 112
# wrong_resized_image_9_300.jpg
# 113
# 114
# right_resized_image_2234.jpg
# 115
# 116
# wrong_resized_image_2197.jpg
# 117
# right_resized_20190103_145240.jpg
# 118
# 119
# wrong_resized_image884.jpg
# 120
# 121
# 122
# right_resized_image_2472 - Copy.jpg
# 123
# 124
# right_resized_image811.jpg
# 125
# right_resized_image_8_270.jpg
# 126
# 127
# wrong_resized_image_6_225.jpg
# 128
# right_resized_image934.jpg
# 129
# right_resized_image_2593.jpg
# 130
# 131
# 132
# 133
# 134
# wrong_resized_image902.jpg
# 135
# right_resized_image_2639 - Copy.jpg
# 136
# right_resized_20190102_192257.jpg
# 137
# wrong_resized_image_6_310.jpg
# 138
# 139
# wrong_resized_image_6_255.jpg
# 140
# 141
# 142
# 143
# wrong_resized_image643.jpg
# 144
# wrong_resized_image_7_1005.jpg
# 145
# 146
# wrong_resized_image_21400.jpg
# 147
# 148
# wrong_resized_20190103_145227.jpg
# 149
# wrong_resized_image_6_385.jpg
# 150
# 151
# 152
# right_resized_image_9_685.jpg
# 153
# wrong_resized_20190103_145051.jpg
# 154
# 155
# 156
# wrong_resized_image_8_350.jpg
# 157
# 158
# wrong_resized_image_2432.jpg
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 416
# 417
# 418
# wrong_resized_image_7_235.jpg
# 419
# 420
# wrong_resized_image_6_15.jpg
# 421
# right_resized_image_2393 - Copy.jpg
# 422
# wrong_resized_image_2557.jpg
# 423
# right_resized_image_5_70.jpg
# 424
# 425
# 426
# 427
# right_resized_image_8_5.jpg
# 428
# 429
# wrong_resized_image_9_385.jpg
# 430
# right_resized_20190103_145332(1).jpg
# 431
# wrong_resized_20190103_144510.jpg
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# wrong_resized_image_21238.jpg
# 441
# 442
# right_resized_20190103_145404.jpg
# 443
# 444
# 445
# 446
# 447
# right_resized_20190103_144947(0).jpg
# 448
# wrong_resized_image_2441.jpg
# 449
# 450
# wrong_resized_image_2527.jpg
# 451
# wrong_resized_image_2704.jpg
# 452
# 453
# 454
# 455
# wrong_resized_image_2237.jpg
# 456
# right_resized_20190103_145010.jpg
# 457
# wrong_resized_image_2363.jpg
# 458
# 459
# 460
# 461
# right_resized_20181231_163312.jpg
# 462
# wrong_resized_image_8_330.jpg
# 463
# right_resized_image_242.jpg
# 464
# 465
# 466
# 467
# wrong_resized_image_2686.jpg
# 468
# wrong_resized_image_2323.jpg
# 469
# right_resized_image_5_450.jpg
# 470
# 471
# 472
# 473
# wrong_resized_image862.jpg
# 474
# right_resized_image_5_420.jpg
# 475
# 476
# 477
# wrong_resized_20190103_155408.jpg
# 478
# 479
# 480
# 481
# right_resized_20190103_145424(1).jpg
# 482
# 483
# 484
# 485
# right_resized_image_410.jpg
# 486
# wrong_resized_image_9_760.jpg
# 487
# 488
# 489
# wrong_resized_image_2200.jpg
# 490
# right_resized_image_8_240.jpg
# 491
# 492
# wrong_resized_image_9_930.jpg
# 493
# right_resized_20190103_144657.jpg
# 494
# 495
# right_resized_image_2232.jpg
# 496
# wrong_resized_20190103_144740.jpg
# 497
# 498
# wrong_resized_image648.jpg
# 499
# wrong_resized_image_7_770.jpg
# 500
# 501
# wrong_resized_image_7_935.jpg
# 502
# 503
# wrong_resized_image_2561.jpg
# 504
# 505
# 506
# wrong_resized_image_2526.jpg
# 507
# wrong_resized_image_2399.jpg
# 508
# 509
# 510
# 511
# 512
# wrong_resized_image901.jpg
# 513
# 514
# right_resized_image_9_95.jpg
# 515
# 516
# 517
# wrong_resized_20190103_145452.jpg
# 518
# 519
# 520
# 521
# wrong_resized_image_7_1300.jpg
# 522
# 523
# wrong_resized_20190106_135837.jpg
# 524
# 525
# right_resized_20190103_145055.jpg
# 526
# 527
# wrong_resized_image_7_905.jpg
# 528
# 529
# 530
# 531
# 532
# 533
# wrong_resized_20190106_135833.jpg
# 534
# wrong_resized_20190103_144427.jpg
# 535
# 536
# 537
# 538
# 539
# 540
# wrong_resized_20190106_135828.jpg
# 541
# right_resized_image_235.jpg
# 542
# wrong_resized_20190103_144958.jpg
# 543
# 544
# 545
# 546
# right_resized_image_9_910.jpg
# 547
# wrong_resized_20190103_144744.jpg
# 548
# wrong_resized_image_2322.jpg
# 549
# wrong_resized_image_9_40.jpg
# 550
# wrong_resized_image_2361.jpg
# 551
# 552
# wrong_resized_image_5_400.jpg
# 553
# 554
# 555
# right_resized_image_9_710.jpg
# 556
# right_resized_image_5_455.jpg
# 557
# wrong_resized_image_6_75.jpg
# 558
# wrong_resized_image_7_175.jpg
# 559
# 560
# wrong_resized_image_2271.jpg
# 561
# 562
# wrong_resized_image_9_475.jpg
# 563
# wrong_resized_20190103_145006.jpg
# 564
# right_resized_image_5_335.jpg
# 565
# 566
# 567
# right_resized_image_9_635.jpg
# 568
# 569
# 570
# 571
# wrong_resized_image_2204.jpg
# 572
# right_resized_20181231_163303.jpg
# 573
# wrong_resized_20190103_155823.jpg
# 574
# 575
# right_resized_image_5_15.jpg
# 576
# 577
# 578
# 579
# 580
# 581
# wrong_resized_image_21401.jpg
# 582
# right_resized_image_9_270.jpg
# 583
# wrong_resized_image_9_900.jpg
# 584
# 585
# 586
# 587
# 588
# 589
# wrong_resized_20190103_145236.jpg
# 590
# wrong_resized_image_9_615.jpg
# 591
# 592
# wrong_resized_image_5_390.jpg
# 593
# right_resized_image_9_850.jpg
# 594
# 595
# 596
# 597
# wrong_resized_20190103_145049.jpg
# 598
# wrong_resized_image_2307.jpg
# 599
# 600
# wrong_resized_20190103_144656.jpg
# 601
# 602
# 603
# 604
# right_resized_image_7_1290.jpg
# 605
# 606
# 607
# right_resized_image_9_580.jpg
# 608
# wrong_resized_20190103_155417.jpg
# 609
# wrong_resized_image_8_10.jpg
# 610
# right_resized_20190103_155212.jpg
# 611
# 612
# 613
# 614
# 615
# wrong_resized_image_2479.jpg
# 616
# 617
# 618
# wrong_resized_image_5_255.jpg
# 619
# 620
# 621
# right_resized_20190103_145328.jpg
# 622
# 623
# 624
# 625
# 626
# 627
# 628
# wrong_resized_image_8_215.jpg
# 629
# 630
# 631
# right_resized_20190103_144934.jpg
# 632
# 633
# 634
# 635
# wrong_resized_image_2155.jpg
# 636
# 637
# wrong_resized_20190102_192254.jpg
# 638
# 639
# wrong_resized_image_7_15.jpg
# 640
# right_resized_image_440.jpg
# 641
# 642
# right_resized_image_2272.jpg
# 643
# right_resized_20190103_145359(0).jpg
# 644
# right_resized_image_8_95.jpg
# 645
# 646
# wrong_resized_image_7_90.jpg
# 647
# 648
# right_resized_20190103_155256.jpg
# 649
# 650
# 651
# right_resized_image_7_1090.jpg
# 652
# wrong_resized_20190103_155841.jpg
# 653
# 654
# wrong_resized_image_7_205.jpg
# 655
# 656
# 657
# 658
# 659
# right_resized_image_243.jpg
# 660
# wrong_resized_image_21415.jpg
# 661
# 662
# wrong_resized_image_6_560.jpg
# 663
# wrong_resized_20190103_144850.jpg
# 664
# wrong_resized_image_21237.jpg
# 665
# 666
# 667
# 668
# 669
# 670
# 671
# right_resized_20190103_144729.jpg
# 672
# 673
# 674
# right_resized_image_6_320.jpg
# 675
# 676
# right_resized_image_5_220.jpg
# 677
# right_resized_image_273.jpg
# 678
# 679
# right_resized_image_5_275.jpg
# 680
# 681
# right_resized_image_6_580.jpg
# 682
# 683
# 684
# wrong_resized_20190103_145441.jpg
# 685
# right_resized_image_9_785.jpg
# 686
# 687
# 688
# 689
# wrong_resized_image_7_1210.jpg
# 690
# 691
# wrong_resized_20181231_163300.jpg
# 692
# wrong_resized_image944.jpg
# 693
# wrong_resized_image_2349.jpg
# 694
# 695
# 696
# wrong_resized_image_9_10.jpg
# 697
# 698
# wrong_resized_image_9_505.jpg
# 699
# wrong_resized_20190103_145044(0).jpg
# 700
# 701
# right_resized_image_7_20.jpg
# 702
# wrong_resized_image926.jpg
# 703
# right_resized_image_7_765.jpg
# 704
# 705
# 706
# 707
# 708
# 709
# wrong_resized_20190103_145432.jpg
# 710
# 711
# 712
# 713
# wrong_resized_image_2196.jpg
# 714
# wrong_resized_20190103_144947.jpg
# 715
# wrong_resized_image_2156.jpg
# 716
# wrong_resized_image_2684.jpg
# 717
# 718
# 719
# 720
# 721
# wrong_resized_20190103_144428(0).jpg
# 722
# wrong_resized_20190103_145044.jpg
# 723
# 724
# wrong_resized_image_2153.jpg
# 725
# 726
# 727
# 728
# 729
# wrong_resized_20190103_145341.jpg
# 730
# wrong_resized_20190103_145332.jpg
# 731
# right_resized_20190103_145243.jpg
# 732
# wrong_resized_image_2283.jpg
# 733
# 734
# 735
# 736
# wrong_resized_image_7_400.jpg
# 737
# right_resized_20190103_145050.jpg
# 738
# 739
# 740
# 741
# 742
# 743
# 744
# 745
# right_resized_image_6_230.jpg
# 746
# 747
# 748
# right_resized_image_5_155.jpg
# 749
# wrong_resized_image_7_385.jpg
# 750
# 751
# wrong_resized_20190103_145332(0).jpg
# 752
# 753
# right_resized_image_5_75.jpg
# 754
# right_resized_20190103_145442.jpg
# 755
# right_resized_image_6_20.jpg
# 756
# 757
# right_resized_image_2473 - Copy.jpg
# 758
# 759
# 760
# 761
# 762
# wrong_resized_image_5_35.jpg
# 763
# 764
# right_resized_image_2636 - Copy.jpg
# 765
# 766
# right_resized_image_470.jpg
# 767
# right_resized_image_9_35.jpg
# 768
# 769
# wrong_resized_20190103_155419(0).jpg
# 770
# 771
# wrong_resized_image_2386.jpg
# 772
# right_resized_20190103_145408.jpg
# 773
# 774
# 775
# right_resized_20190103_144704.jpg
# 776
# right_resized_image_6_525.jpg
# 777
# 778
# wrong_resized_image_2677.jpg
# 779
# 780
# 781
# 782
# wrong_resized_image_2168.jpg
# 783
# 784
# 785
# 786
# 787
# 788
# wrong_resized_20190103_145337.jpg
# 789
# 790
# 791
# 792
# 793
# 794
# 795
# 796
# wrong_resized_image_2282.jpg
# 797
# 798
# 799
# right_resized_image_7_230.jpg
# 800
# wrong_resized_image_2202.jpg
# 801
# wrong_resized_20190103_144937.jpg
# 802
# 803
# 804
# wrong_resized_image_7_1050.jpg
# 805
# 806
# 807
# right_resized_20190103_145416.jpg
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# wrong_resized_image_9_405.jpg
# 815
# 816
# wrong_resized_image_2277.jpg
# 817
# 818
# right_resized_image_2511.jpg
# 819
# wrong_resized_image_350.jpg
# 820
# 821
# 822
# right_resized_image_31800.jpg
# 823
# wrong_resized_image_7_1150.jpg
# 824
# 825
# wrong_resized_20190103_144428.jpg
# 826
# 827
# wrong_resized_image_7_1270.jpg
# 828
# wrong_resized_image864.jpg
# 829
# wrong_resized_image_284.jpg
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# wrong_resized_image_2350.jpg
# 839
# 840
# 841
# 842
# wrong_resized_20190103_155325.jpg
# 843
# 844
# wrong_resized_image_7_295.jpg
# 845
# 846
# wrong_resized_20190103_144501.jpg
# 847
# wrong_resized_image_2244.jpg
# 848
# right_resized_20190103_144950.jpg
# 849
# 850
# wrong_resized_image_7_440.jpg
# 851
# 852
# right_resized_image_7_320.jpg
# 853
# right_resized_image_5_305.jpg
# 854
# 855
# right_resized_image_7_820.jpg
# 856
# wrong_resized_image_2123.jpg
# 857
# right_resized_image_9_355.jpg
# 858
# 859
# right_resized_20190103_144941.jpg
# 860
# 861
# 862
# 863
# 864
# wrong_resized_20190103_144505.jpg
# 865
# 866
# 867
# 868
# 869
# wrong_resized_20190103_145052.jpg
# 870
# right_resized_image_2594.jpg
# 871
# 872
# wrong_resized_image_6_175.jpg
# 873
# wrong_resized_image_2166.jpg
# 874
# 875
# 876
# 877
# right_resized_20190103_145445.jpg
# 878
# wrong_resized_image_9_575.jpg
# 879
# 880
# 881
# 882
# wrong_resized_image_2241.jpg
# 883
# 884
# 885
# 886
# right_resized_20190103_144954.jpg
# 887
# 888
# 889
# wrong_resized_20190103_145432(0).jpg
# 890
# 891
# wrong_resized_20190103_145412.jpg
# 892
# 893
# wrong_resized_image_9_870.jpg
# 894
# right_resized_image_6_345.jpg
# 895
# wrong_resized_image649.jpg
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# wrong_resized_image923.jpg
# 907
# 908
# wrong_resized_image_9_730.jpg
# 909
# wrong_resized_20190103_145437(1).jpg
# 910
# 911
# 912
# wrong_resized_20181231_163237.jpg
# 913
# wrong_resized_image_2563.jpg
# 914
# wrong_resized_image_9_155.jpg
# 915
# 916
# 917
# right_resized_image_7_1295.jpg
# 918
# 919
# wrong_resized_image_2436.jpg
# 920
# 921
# right_resized_image_2555.jpg
# 922
# 923
# wrong_resized_20190106_135834.jpg
# 924
# 925
# 926
# 927
# 928
# wrong_resized_image_6_60.jpg
# 929
# wrong_resized_image_21402.jpg
# 930
# 931
# right_resized_20190103_145244.jpg
# 932
# 933
# wrong_resized_image_9_490.jpg
# 934
# 935
# 936
# 937
# wrong_resized_image_9_145.jpg
# 938
# right_resized_image_5_10.jpg
# 939
# 940
# 941
# wrong_resized_image_2146.jpg
# 942
# 943
# wrong_resized_image_6_30.jpg
# 944
# wrong_resized_image_2240.jpg
# 945
# 946
# 947
# 948
# right_resized_image_9_210.jpg
# 949
# 950
# 951
# right_resized_image_2192.jpg
# 952
# 953
# wrong_resized_image_9_360.jpg
# 954
# right_resized_20190103_155258.jpg
# 955
# 956
# wrong_resized_image_7_945.jpg
# 957
# 958
# wrong_resized_image_9_350.jpg
# 959
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# wrong_resized_image_8_145.jpg
# 1083
# 1084
# 1085
# right_resized_image_5_365.jpg
# 1086
# 1087
# wrong_resized_image924.jpg
# 1088
# wrong_resized_20190103_155819.jpg
# 1089
# right_resized_image_7_855.jpg
# 1090
# 1091
# 1092
# wrong_resized_20190103_155614.jpg
# 1093
# 1094
# 1095
# right_resized_image_2311.jpg
# 1096
# wrong_resized_image_7_580.jpg
# 1097
# 1098
# right_resized_20190103_145019.jpg
# 1099
# 1100
# 1101
# wrong_resized_image_2525.jpg
# 1102
# wrong_resized_image866.jpg
# 1103
# 1104
# right_resized_20190103_145314.jpg
# 1105
# 1106
# right_resized_image_9_690.jpg
# 1107
# right_resized_20190103_144735.jpg
# 1108
# 1109
# 1110
# 1111
# 1112
# right_resized_image_2435.jpg
# 1113
# 1114
# wrong_resized_image_9_290.jpg
# 1115
# wrong_resized_image931.jpg
# 1116
# 1117
# wrong_resized_image_2472.jpg
# 1118
# right_resized_20190103_145323.jpg
# 1119
# right_resized_image_2314.jpg
# 1120
# 1121
# wrong_resized_image_8_300.jpg
# 1122
# right_resized_image_6_550.jpg
# 1123
# 1124
# 1125
# 1126
# right_resized_image_2352.jpg
# 1127
# right_resized_image_2315.jpg
# 1128
# 1129
# wrong_resized_image_9_640.jpg
# 1130
# 1131
# wrong_resized_image_2148.jpg
# 1132
# 1133
# wrong_resized_image_2205.jpg
# 1134
# 1135
# wrong_resized_image_2723.jpg
# 1136
# 1137
# wrong_resized_20190103_145346.jpg
# 1138
# wrong_resized_image_2201.jpg
# 1139
# wrong_resized_20190103_145432(1).jpg
# 1140
# 1141
# wrong_resized_image_9_855.jpg
# 1142
# 1143
# right_resized_20181231_163147.jpg
# 1144
# wrong_resized_image_9_185.jpg
# 1145
# right_resized_image_9_790.jpg
# 1146
# 1147
# wrong_resized_20190103_155401.jpg
# 1148
# 1149
# wrong_resized_image_2522.jpg

# %%
print(f"""out of {len(point_df)} images that the algorithm was able to process, 
{int(point_df.label.sum())} were of correct squats while {int(len(point_df)-point_df.label.sum())} were of bad form""")
# Out:
# out of 630 images that the algorithm was able to process,
# 266 were of correct squats while 364 were of bad form

# %% [markdown]
# ## Logistic Regression of NN results

# %%
labels = point_df['label']

# %%
features = point_df.iloc[:,:-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = 0.2)

# %%
y_test.sum()
# Out:
# 50.0

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()

# %%
classifier.fit(X_train, y_train)
# Out:
# /home/roee/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = classifier.predict(X_test)

# %%
print(f"""Logistic regression resulted in correct prediction in {round(classifier.score(X_test, y_test)*100, 2)}% 
of images successfully processed""")
# Out:
# Logistic regression resulted in correct prediction in 81.75%
# of images successfully processed
