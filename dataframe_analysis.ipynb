# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/romanrosh/PycharmProjects/bio-mechanic-movmement-detector-ai/destination/Data for fit/all_squats_from_pics.csv')

# %%
head_x = (df.loc[:,['0-XNose','15-XREye','16-XLEye','17-XREar','18-XLEar']])

# %%
head_y = (df.loc[:,['0-YNose','15-YREye','16-YLEye','17-YREar','18-YLEar']])

# %%
df['XHead']=head_x.apply(np.mean, axis=1)

# %%
df['YHead']=head_y.apply(np.mean, axis=1)

# %%
# df.loc[:,['XHead', 'YHead']]

# %%
plt.plot(df['XHead'])

# %%
plt.plot(df['YHead'])

# %%
plt.plot(df['YHead'])

# %%
plt.plot(df['YHead'])

# %%
# clean_df = df.iloc[50:, :]

# %%
labels = []
df['label'] = np.zeros(df.shape[0])
length = df.shape[0]
for index in np.arange(1, length-1):
    if df['YHead'][index]>df['YHead'][index-1] and df['YHead'][index]>df['YHead'][index+1]:
        df.label[index] = 'bottom'
    elif df['YHead'][index]<df['YHead'][index-1] and df['YHead'][index]<df['YHead'][index+1]:
        df.label[index] = 'top'
    else:
        df.label[index] ='midway'
# Out:
# C:\Users\romanrosh\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\romanrosh\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\romanrosh\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# ...

# %%
df
# Out:
#       0-XNose  0-YNose  1-XNeck  1-YNeck  2-XRShoulder  2-YRShoulder  \
# 0       382.0    313.0    400.0    339.0         330.0         339.0
# 1       400.0    313.0    400.0    339.0         347.0         339.0
# 2       400.0    273.0    400.0    300.0         347.0         286.0
# 3       400.0    365.0    400.0    352.0         347.0         352.0
# 4       365.0    300.0    382.0    339.0         313.0         339.0
# 5       365.0    247.0    365.0    313.0         295.0         313.0
# 6       365.0    247.0    365.0    300.0         295.0         313.0
# 7       400.0    260.0    400.0    326.0         330.0         326.0
# 8       382.0    260.0    382.0    313.0         313.0         313.0
# 9       400.0    260.0    400.0    313.0         330.0         313.0
# 10      382.0    247.0    382.0    300.0         313.0         286.0
# 11      382.0    273.0    382.0    313.0         313.0         313.0
# 12      382.0    273.0    382.0    313.0         330.0         313.0
# ...

# %%
df = df.iloc[1:-1]
df
# Out:
#      Unnamed: 0  0-XNose     0-YNose  1-XNeck     1-YNeck  2-XRShoulder  \
# 1             1      347  172.000000    320.0  187.000000    306.000000
# 2             2      347  180.000000    320.0  203.000000    320.000000
# 3             3      347  140.000000    320.0  164.000000    320.000000
# 4             4      333  101.000000    320.0  125.000000    306.000000
# 5             5      333  101.000000    320.0  125.000000    306.000000
# 6             6      333  117.000000    320.0  140.000000    306.000000
# 7             7      347  164.000000    320.0  187.000000    306.000000
# 8             8      347  123.090909    320.0  146.181818    308.776860
# 9             9      347  140.000000    320.0  164.000000    306.483847
# 10           10      333  101.000000    320.0  125.000000    306.000000
# 11           11      333  101.000000    320.0  125.000000    306.000000
# 12           12      333  101.000000    320.0  125.000000    306.000000
# ...

# %%
print(df.label.tail(15))
plt.plot(df.YHead.tail(15))
# Out:
# 1136    top
# 1137    top
# 1138    top
# 1139    top
# 1140    top
# 1141    top
# 1142    top
# 1143    top
# 1144    top
# 1145    top
# 1146    top
# 1147    top
# 1148    top
# 1149    top
# 1150    top
# Name: label, dtype: object

# %%
for i in np.arange(200, df.shape[0]):
    print(f"height: {df.YHead[i]}, label: {df.label[i]}")

# %%
top_points = df[df.label=='top']

# %%
bottom_points = df[df.label=='bottom']

# %%
# top_points.to_csv('./destination/top points.csv')

# %%
# bottom_points.to_csv('./destination/bottom points.csv')

# %%
df[:].to_csv('./destination/Data for fit/all_squats_from_pics.csv-all labeled.csv')

# %%
df2 = pd.read_csv('./destination/top points.csv')
df3 = pd.read_csv('./destination/bottom points.csv')
df4 = pd.read_csv('./destination/all labeled.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-98-6fd915a5bafa> in <module>()
# ----> 1 df2 = pd.read_csv('./destination/top points.csv')
#       2 df3 = pd.read_csv('./destination/bottom points.csv')
#       3 df4 = pd.read_csv('./destination/all labeled.csv')
#
# ...

# %%
df4
