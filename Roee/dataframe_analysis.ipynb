# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output_roee2.csv')

# %%
head_x = (df.loc[:,['0-XNose','15-XREye','16-XLEye','17-XREar','18-XLEar']])

# %%
head_y = (df.loc[:,['0-YNose','15-YREye','16-YLEye','17-YREar','18-YLEar']])

# %%
df['XHead']=head_x.apply(np.mean, axis=1)

# %%
df['YHead']=head_y.apply(np.mean, axis=1)

# %%
# df.loc[:,['XHead', 'YHead']]

# %%
plt.plot(df['XHead'])

# %%
plt.plot(df['YHead'])

# %%
plt.plot(df['YHead'][150:])

# %%
plt.plot(df['YHead'][190:])

# %%
clean_df = df.iloc[190:, :]

# %%
labels = []
df['label'] = np.zeros(df.shape[0])
length = df.shape[0]
for index in np.arange(1, length-1):
    if df['YHead'][index]>df['YHead'][index-1] and df['YHead'][index]>df['YHead'][index+1]:
        df.label[index] = 'bottom'
    elif df['YHead'][index]<df['YHead'][index-1] and df['YHead'][index]<df['YHead'][index+1]:
        df.label[index] = 'top'
    else:
        df.label[index] ='midway'
# Out:
# /home/roee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/roee/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/roee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/roee/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = df.iloc[:-1]

# %%
print(df.label.tail(15))
plt.plot(df.YHead.tail(15))
# Out:
# 415       top
# 416    midway
# 417    bottom
# 418    midway
# 419    midway
# 420       top
# 421    midway
# 422    midway
# 423    midway
# 424    bottom
# 425    midway
# 426       top
# 427    midway
# 428    midway
# 429    bottom
# Name: label, dtype: object

# %%
for i in np.arange(200, df.shape[0]):
    print(f"height: {df.YHead[i]}, label: {df.label[i]}")
# Out:
# height: 137.68168948213062, label: midway
# height: 160.6715805659108, label: midway
# height: 185.4715805659108, label: top
# height: 167.0715805659108, label: midway
# height: 134.27158056591082, label: midway
# height: 128.80603711215747, label: bottom
# height: 134.27158056591082, label: midway
# height: 165.4715805659108, label: midway
# height: 183.87158056591082, label: top
# height: 160.08838763419163, label: midway
# height: 129.4715805659108, label: midway
# height: 125.3623369068309, label: bottom
# height: 135.87158056591082, label: midway
# height: 167.0715805659108, label: midway
# height: 174.41686538915536, label: top
# height: 160.6715805659108, label: midway
# height: 131.0715805659108, label: midway
# height: 130.04327887960466, label: bottom
# height: 134.27158056591082, label: midway
# height: 165.4715805659108, label: midway
# height: 183.87158056591082, label: top
# height: 158.868435934099, label: midway
# height: 129.4715805659108, label: bottom
# height: 129.89618748693434, label: midway
# height: 134.27158056591082, label: midway
# height: 167.0715805659108, label: midway
# height: 182.4715805659108, label: top
# height: 158.59965643103877, label: midway
# height: 135.71076754214988, label: midway
# height: 131.66830685004751, label: bottom
# height: 144.87158056591082, label: midway
# height: 171.87158056591082, label: midway
# height: 179.6715805659108, label: top
# height: 149.4715805659108, label: midway
# height: 123.0715805659108, label: midway
# height: 121.47158056591081, label: bottom
# height: 146.27158056591082, label: midway
# height: 169.98269167702193, label: midway
# height: 179.6715805659108, label: top
# height: 147.87158056591082, label: midway
# height: 121.47158056591081, label: bottom
# height: 129.46170402270096, label: midway
# height: 146.27158056591082, label: midway
# height: 178.27158056591082, label: midway
# height: 178.27158056591082, label: midway
# height: 143.4715805659108, label: midway
# height: 130.7593720611097, label: bottom
# height: 131.5603597154307, label: midway
# height: 147.97431611318217, label: midway
# height: 178.27158056591082, label: top
# height: 171.87158056591082, label: midway
# height: 137.4715805659108, label: midway
# height: 123.0715805659108, label: bottom
# height: 133.49158056591082, label: midway
# height: 155.87158056591082, label: midway
# height: 183.87158056591082, label: top
# height: 167.0715805659108, label: midway
# height: 135.87158056591082, label: midway
# height: 116.67158056591082, label: bottom
# height: 133.4715805659108, label: midway
# height: 155.87158056591082, label: midway
# height: 183.87158056591082, label: top
# height: 167.0715805659108, label: midway
# height: 134.27158056591082, label: midway
# height: 126.92612602045627, label: bottom
# height: 136.6715805659108, label: midway
# height: 160.6715805659108, label: midway
# height: 177.18199378905132, label: top
# height: 160.6715805659108, label: midway
# height: 136.6715805659108, label: midway
# height: 130.43158056591082, label: bottom
# height: 135.87158056591082, label: midway
# height: 167.0715805659108, label: midway
# height: 183.87158056591082, label: top
# height: 154.27158056591082, label: midway
# height: 124.67158056591082, label: bottom
# height: 127.5715805659108, label: midway
# height: 140.6715805659108, label: midway
# height: 171.87158056591082, label: midway
# height: 179.6715805659108, label: top
# height: 152.6715805659108, label: midway
# height: 123.0715805659108, label: bottom
# height: 127.59158056591082, label: midway
# height: 142.0715805659108, label: midway
# height: 173.4715805659108, label: midway
# height: 179.6715805659108, label: top
# height: 147.87158056591082, label: midway
# height: 123.0715805659108, label: bottom
# height: 129.03158056591082, label: midway
# height: 142.0715805659108, label: midway
# height: 173.4715805659108, label: midway
# height: 178.27158056591082, label: top
# height: 146.27158056591082, label: midway
# height: 121.47158056591081, label: bottom
# height: 127.13158056591082, label: midway
# height: 142.0715805659108, label: midway
# height: 173.4715805659108, label: midway
# height: 178.27158056591082, label: top
# height: 143.4715805659108, label: midway
# height: 127.86491389924416, label: bottom
# height: 131.1382472325775, label: midway
# height: 147.87158056591082, label: midway
# height: 179.6715805659108, label: top
# height: 171.87158056591082, label: midway
# height: 140.6715805659108, label: midway
# height: 127.15491389924416, label: bottom
# height: 130.4569972325775, label: midway
# height: 154.27158056591082, label: midway
# height: 174.5449444354868, label: top
# height: 164.9385448516251, label: midway
# height: 140.30549744635547, label: midway
# height: 127.20312818495843, label: bottom
# height: 134.02697077755104, label: midway
# height: 154.22201413439993, label: midway
# height: 174.12153283351054, label: top
# height: 164.7638450927928, label: midway
# height: 139.7169029336415, label: midway
# height: 126.43899874811075, label: bottom
# height: 132.91538476197195, label: midway
# height: 154.27158056591082, label: midway
# height: 174.9087050683993, label: top
# height: 163.87158056591082, label: midway
# height: 135.76355259391954, label: midway
# height: 127.51954859792079, label: bottom
# height: 137.4268086106041, label: midway
# height: 164.1282372425806, label: midway
# height: 178.54964261957178, label: top
# height: 159.55680867115206, label: midway
# height: 136.14531216765096, label: midway
# height: 128.2235326138672, label: bottom
# height: 142.06752661986175, label: midway
# height: 167.0715805659108, label: midway
# height: 175.98566823310904, label: top
# height: 156.7373036319132, label: midway
# height: 133.36506782864925, label: midway
# height: 128.60775973049698, label: bottom
# height: 141.39002066887826, label: midway
# height: 167.0715805659108, label: midway
# height: 176.31071039079936, label: top
# height: 155.7043900555286, label: midway
# height: 133.3927041476863, label: midway
# height: 128.59082219983497, label: bottom
# height: 145.48072740407548, label: midway
# height: 171.87158056591082, label: midway
# height: 178.27158056591082, label: top
# height: 146.27158056591082, label: midway
# height: 131.39695706280958, label: midway
# height: 130.20503289941715, label: bottom
# height: 142.0715805659108, label: midway
# height: 173.4715805659108, label: midway
# height: 175.0715805659108, label: top
# height: 142.0715805659108, label: midway
# height: 116.67158056591082, label: bottom
# height: 118.27158056591081, label: midway
# height: 142.0715805659108, label: midway
# height: 167.20491389924413, label: midway
# height: 173.4715805659108, label: top
# height: 142.0715805659108, label: midway
# height: 123.0715805659108, label: bottom
# height: 128.6641731585034, label: midway
# height: 146.27158056591082, label: midway
# height: 178.27158056591082, label: top
# height: 173.4715805659108, label: midway
# height: 140.6715805659108, label: midway
# height: 130.2456546399849, label: bottom
# height: 130.8686999074746, label: midway
# height: 146.27158056591082, label: midway
# height: 172.1004475182626, label: top
# height: 166.66797974286553, label: midway
# height: 140.6715805659108, label: midway
# height: 125.68353576606046, label: bottom
# height: 128.89613046303015, label: midway
# height: 150.18501935191904, label: midway
# height: 171.2970661516868, label: top
# height: 168.6715805659108, label: midway
# height: 134.27158056591082, label: midway
# height: 125.96382915130175, label: bottom
# height: 127.87158056591082, label: midway
# height: 157.51333036382383, label: midway
# height: 175.3370306947383, label: top
# height: 162.77643747781138, label: midway
# height: 129.4715805659108, label: midway
# height: 124.98990640463751, label: bottom
# height: 134.23435084908195, label: midway
# height: 160.6715805659108, label: midway
# height: 173.39017586929066, label: top
# height: 163.87158056591082, label: midway
# height: 129.4715805659108, label: midway
# height: 116.67158056591082, label: bottom
# height: 129.4715805659108, label: midway
# height: 162.27158056591082, label: midway
# height: 187.0715805659108, label: top
# height: 167.0715805659108, label: midway
# height: 134.27158056591082, label: midway
# height: 128.03158056591082, label: bottom
# height: 135.87158056591082, label: midway
# height: 165.4715805659108, label: midway
# height: 185.4715805659108, label: top
# height: 160.6715805659108, label: midway
# height: 129.4715805659108, label: midway
# height: 121.47158056591081, label: bottom
# height: 141.0965805659108, label: midway
# height: 172.0, label: midway
# height: 185.4715805659108, label: top
# height: 157.9997055659108, label: midway
# height: 127.87158056591082, label: bottom
# height: 131.61572119091082, label: midway
# height: 146.4796100797997, label: midway
# height: 173.4715805659108, label: midway
# height: 181.0715805659108, label: top
# height: 152.6715805659108, label: midway
# height: 131.86626613689845, label: midway
# height: 123.0715805659108, label: bottom
# height: 146.27158056591082, label: midway
# height: 172.47091626228428, label: midway
# height: 178.27158056591082, label: top
# height: 143.4715805659108, label: midway
# height: 121.47158056591081, label: bottom
# height: 129.2464975279575, label: midway
# height: 150.3576086390686, label: midway
# height: 182.4715805659108, label: top
# height: 171.87158056591082, label: midway
# height: 135.87158056591082, label: midway
# height: 126.37767506943126, label: midway
# height: 123.0715805659108, label: bottom
# height: 152.6715805659108, label: midway
# height: 181.0715805659108, label: top
# height: 168.8, label: midway
# height: 134.4, label: midway
# height: 121.6, label: bottom

# %%
top_points = df[df.label=='top']

# %%
bottom_points = df[df.label=='bottom']

# %%
top_points.to_csv('top points.csv')

# %%
bottom_points.to_csv('bottom points.csv')

# %%
df[200:].to_csv('all labeled.csv')

# %%
label = 'mid'
for d in df.YHead:
    if

# %%
df2 = pd.read_csv('top points.csv')
df3 = pd.read_csv('bottom points.csv')
df4 = pd.read_csv('all labeled.csv')

# %%
df4.label
# Out:
# 0      midway
# 1      midway
# 2         top
# 3      midway
# 4      midway
# 5      bottom
# 6      midway
# 7      midway
# 8         top
# 9      midway
# 10     midway
# 11     bottom
# 12     midway
# 13     midway
# 14        top
# 15     midway
# 16     midway
# 17     bottom
# 18     midway
# 19     midway
# 20        top
# 21     midway
# 22     bottom
# 23     midway
# 24     midway
# 25     midway
# 26        top
# 27     midway
# 28     midway
# 29     bottom
#         ...
# 200    bottom
# 201    midway
# 202    midway
# 203       top
# 204    midway
# 205    bottom
# 206    midway
# 207    midway
# 208    midway
# 209       top
# 210    midway
# 211    midway
# 212    bottom
# 213    midway
# 214    midway
# 215       top
# 216    midway
# 217    bottom
# 218    midway
# 219    midway
# 220       top
# 221    midway
# 222    midway
# 223    midway
# 224    bottom
# 225    midway
# 226       top
# 227    midway
# 228    midway
# 229    bottom
# Name: label, Length: 230, dtype: object
